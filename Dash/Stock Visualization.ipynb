# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.plotly as py
import plotly
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("Stocks/aapl.us.txt")
df.head()
# Out:
#          Date     Open     High      Low    Close    Volume  OpenInt
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0

# %%
df.iloc[0:5,:]
# Out:
#          Date     Open     High      Low    Close    Volume  OpenInt
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0

# %%
df.shape
# Out:
# (8364, 7)

# %%
apple = []
for i in range(0, 8364):
    apple.append('AAPL')

df['Stock'] = apple
df['Stock'].shape
# Out:
# (8364,)

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close    Volume  OpenInt Stock
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0  AAPL
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0  AAPL
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0  AAPL
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0  AAPL
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0  AAPL

# %%
df2 = pd.read_csv("Stocks/tsla.us.txt")
df2.head()
# Out:
#          Date   Open   High    Low  Close    Volume  OpenInt
# 0  2010-06-28  17.00  17.00  17.00  17.00         0        0
# 1  2010-06-29  19.00  25.00  17.54  23.89  18783276        0
# 2  2010-06-30  25.79  30.42  23.30  23.83  17194394        0
# 3  2010-07-01  25.00  25.92  20.27  21.96   8229863        0
# 4  2010-07-02  23.00  23.10  18.71  19.20   5141807        0

# %%
df2.shape
# Out:
# (1858, 7)

# %%
tesla = []
for i in range(0, 1858):
    tesla.append('TSLA')

df2['Stock'] = tesla
df2['Stock'].shape
# Out:
# (1858,)

# %%
df3 = pd.read_csv("Stocks/msft.us.txt")
df3.head()
# Out:
#          Date     Open     High      Low    Close      Volume  OpenInt
# 0  1986-03-13  0.06720  0.07533  0.06720  0.07533  1371330506        0
# 1  1986-03-14  0.07533  0.07533  0.07533  0.07533   409569463        0
# 2  1986-03-17  0.07533  0.07533  0.07533  0.07533   176995245        0
# 3  1986-03-18  0.07533  0.07533  0.07533  0.07533    90067008        0
# 4  1986-03-19  0.07533  0.07533  0.07533  0.07533    63655515        0

# %%
df3.shape[0]
# Out:
# 7983

# %%
microsoft = []
for i in range(0, 7983):
    microsoft.append('MSFT')

df3['Stock'] = microsoft
df3['Stock'].shape
# Out:
# (7983,)

# %%
df4 = pd.read_csv("Stocks/fb.us.txt")
df4.head()
# Out:
#          Date   Open   High    Low  Close     Volume  OpenInt
# 0  2012-05-18  42.05  45.00  38.00  38.23  580438450        0
# 1  2012-05-21  36.53  36.66  33.00  34.03  169418988        0
# 2  2012-05-22  32.61  33.59  30.94  31.00  101876406        0
# 3  2012-05-23  31.37  32.50  31.36  32.00   73678512        0
# 4  2012-05-24  32.95  33.21  31.77  33.03   42560731        0

# %%
df4.shape
# Out:
# (1381, 7)

# %%
facebook = []
for i in range(0, 1381):
    facebook.append('FB')

df4['Stock'] = facebook
df4['Stock'].shape
# Out:
# (1381,)

# %%
df4.head()
# Out:
#          Date   Open   High    Low  Close     Volume  OpenInt Stock
# 0  2012-05-18  42.05  45.00  38.00  38.23  580438450        0    FB
# 1  2012-05-21  36.53  36.66  33.00  34.03  169418988        0    FB
# 2  2012-05-22  32.61  33.59  30.94  31.00  101876406        0    FB
# 3  2012-05-23  31.37  32.50  31.36  32.00   73678512        0    FB
# 4  2012-05-24  32.95  33.21  31.77  33.03   42560731        0    FB

# %%
df_new = pd.concat([df,df2,df3,df4],ignore_index=True)

# %%
df_new.tail()
# Out:
#              Date    Open     High      Low   Close    Volume  OpenInt Stock
# 19581  2017-11-06  178.56  180.450  178.310  180.17  13275578        0    FB
# 19582  2017-11-07  180.50  180.748  179.403  180.25  12903836        0    FB
# 19583  2017-11-08  179.79  180.350  179.110  179.56  10467606        0    FB
# 19584  2017-11-09  178.31  179.400  177.090  179.30  12602188        0    FB
# 19585  2017-11-10  178.35  179.100  177.960  178.46  11060355        0    FB

# %%
df_new.shape
# Out:
# (19586, 8)

# %%
df_new.to_csv('stock_data.csv', sep=',', index=False)

# %%
df5 = pd.read_csv("stock_data.csv")
df5.head()
# Out:
#          Date     Open     High      Low    Close    Volume  OpenInt Stock
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0  AAPL
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0  AAPL
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0  AAPL
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0  AAPL
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0  AAPL

# %%
df5.tail()
# Out:
#              Date    Open     High      Low   Close    Volume  OpenInt Stock
# 19581  2017-11-06  178.56  180.450  178.310  180.17  13275578        0    FB
# 19582  2017-11-07  180.50  180.748  179.403  180.25  12903836        0    FB
# 19583  2017-11-08  179.79  180.350  179.110  179.56  10467606        0    FB
# 19584  2017-11-09  178.31  179.400  177.090  179.30  12602188        0    FB
# 19585  2017-11-10  178.35  179.100  177.960  178.46  11060355        0    FB

# %%
df5.describe().ix[:,0]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# count    19586.000000
# mean        37.408582
# std         59.492049
# min          0.067200
# 25%          1.412300
# 50%         19.649500
# 75%         38.605000
# max        386.690000
# Name: Open, dtype: float64

# %%
d.iloc[:,:]
# Out:
#                Open          High           Low         Close        Volume  \
# count  19586.000000  19586.000000  19586.000000  19586.000000  1.958600e+04
# mean      37.408582     37.881571     36.906405     37.406667  8.100395e+07
# std       59.492049     60.287797     58.622548     59.480058  7.982366e+07
# min        0.067200      0.067200      0.067200      0.067200  0.000000e+00
# 25%        1.412300      1.440600      1.384100      1.412300  3.385552e+07
# 50%       19.649500     19.933000     19.363000     19.640000  6.294731e+07
# 75%       38.605000     39.075750     38.229250     38.655500  1.010604e+08
# max      386.690000    389.610000    379.345000    385.000000  2.069770e+09
#
#        OpenInt
# count  19586.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
df[['Close']].plot()
plt.title("Apple")
plt.show()

# %%
df2[['Close']].plot()
plt.title("Tesla")
plt.show()

# %%
df3[['Close']].plot()
plt.title("Microsoft")
plt.show()

# %%
df4[['Close']].plot()
plt.title("Facebook")
plt.show()

# %%
df5[df5['Stock'] == 'AAPL']['High'][-1000:]
# Out:
# 7364     69.156
# 7365     69.650
# 7366     71.010
# 7367     72.316
# 7368     73.948
# 7369     74.742
# 7370     75.012
# 7371     75.386
# 7372     76.175
# 7373     75.063
# 7374     75.439
# 7375     75.213
# 7376     75.622
# 7377     74.877
# 7378     74.552
# 7379     74.518
# 7380     74.096
# 7381     73.037
# 7382     72.844
# 7383     73.056
# 7384     75.588
# 7385     75.741
# 7386     75.428
# 7387     74.753
# 7388     74.182
# 7389     74.338
# 7390     73.776
# 7391     73.334
# 7392     72.421
# 7393     72.311
#          ...
# 8334    153.900
# 8335    154.530
# 8336    153.310
# 8337    154.880
# 8338    154.930
# 8339    156.170
# 8340    157.430
# 8341    156.420
# 8342    156.810
# 8343    156.720
# 8344    159.430
# 8345    160.290
# 8346    160.130
# 8347    156.520
# 8348    157.180
# 8349    157.130
# 8350    156.860
# 8351    156.990
# 8352    157.260
# 8353    163.010
# 8354    167.470
# 8355    169.040
# 8356    169.330
# 8357    167.900
# ...

# %%
plt.scatter(df5[df5['Stock'] == 'AAPL']['High'][-1000:], df5[df5['Stock'] == 'FB']['High'][-1000:])

# %%
plt.scatter(df5[df5['Stock'] == 'AAPL']['Low'][-1000:], df5[df5['Stock'] == 'MSFT']['Low'][-1000:])

# %%
plt.scatter(df5[df5['Stock'] == 'AAPL']['High'][-1000:], df5[df5['Stock'] == 'MSFT']['High'][-1000:])

# %%
plt.scatter(df5[df5['Stock'] == 'AAPL']['Volume'][-1000:], df5[df5['Stock'] == 'TSLA']['Volume'][-1000:])

# %%
dropdown = {"TSLA": "Tesla", "AAPL": "Apple", "FB": "Facebook", "MSFT": "Microsoft", }
dropdown['TSLA']
# Out:
# 'Tesla'

# %%
trace_high = go.Scatter(
    x=df.Date,
    y=df['High'],
    name = "APPLE High",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

trace_low = go.Scatter(
    x=df.Date,
    y=df['Low'],
    name = "APPLE Low",
    line = dict(color = '#7F7F7F'),
    opacity = 0.8)

data = [trace_high,trace_low]

layout = dict(
    title='Time Series with Rangeslider',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    )
)

fig = dict(data=data, layout=layout)
iplot(fig, filename = "Time Series with Rangeslider")
# Out:
# <div>
#
#
#             <div id="73cfc552-2476-4899-bc19-9b81a2f4edf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("73cfc552-2476-4899-bc19-9b81a2f4edf4")) {
#                     Plotly.newPlot(
#                         '73cfc552-2476-4899-bc19-9b81a2f4edf4',
# ...

# %%
trace_high = go.Scatter(
    x=df2.Date,
    y=df2['High'],
    name = "Tesla High",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

trace_low = go.Scatter(
    x=df2.Date,
    y=df2['Low'],
    name = "Tesla Low",
    line = dict(color = '#7F7F7F'),
    opacity = 0.8)

data = [trace_high,trace_low]

layout = dict(
    title='Time Series with Rangeslider',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    )
)

fig = dict(data=data, layout=layout)
iplot(fig, filename = "Time Series with Rangeslider")
# Out:
# <div>
#
#
#             <div id="5acff8d7-fdb6-4792-9e93-c4d84dd34996" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5acff8d7-fdb6-4792-9e93-c4d84dd34996")) {
#                     Plotly.newPlot(
#                         '5acff8d7-fdb6-4792-9e93-c4d84dd34996',
# ...

# %%
trace_high = go.Scatter(
    x=df3.Date,
    y=df3['High'],
    name = "Microsoft High",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

trace_low = go.Scatter(
    x=df3.Date,
    y=df3['Low'],
    name = "Microsoft Low",
    line = dict(color = '#7F7F7F'),
    opacity = 0.8)

data = [trace_high,trace_low]

layout = dict(
    title='Time Series with Rangeslider',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    )
)

fig = dict(data=data, layout=layout)
iplot(fig, filename = "Time Series with Rangeslider")
# Out:
# <div>
#
#
#             <div id="69f7ba04-51b9-4546-83ae-6fe474b1b712" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("69f7ba04-51b9-4546-83ae-6fe474b1b712")) {
#                     Plotly.newPlot(
#                         '69f7ba04-51b9-4546-83ae-6fe474b1b712',
# ...

# %%
trace_high = go.Scatter(
    x=df4.Date,
    y=df4['High'],
    name = "Facebook High",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

trace_low = go.Scatter(
    x=df4.Date,
    y=df4['Low'],
    name = "Facebook Low",
    line = dict(color = '#7F7F7F'),
    opacity = 0.8)

data = [trace_high,trace_low]

layout = dict(
    title='Time Series with Rangeslider',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label='1m',
                     step='month',
                     stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(
            visible = True
        ),
        type='date'
    )
)

fig = dict(data=data, layout=layout)
iplot(fig, filename = "Time Series with Rangeslider")
# Out:
# <div>
#
#
#             <div id="5722b7bb-9182-4efd-9c66-d8b4975a20b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5722b7bb-9182-4efd-9c66-d8b4975a20b1")) {
#                     Plotly.newPlot(
#                         '5722b7bb-9182-4efd-9c66-d8b4975a20b1',
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
df5.head()
# Out:
#          Date     Open     High      Low    Close    Volume  OpenInt Stock
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0  AAPL
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0  AAPL
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0  AAPL
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0  AAPL
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0  AAPL

# %%
train_data, test_data = df5[df5['Stock'] == 'AAPL'][-1000:][0:int(1000*0.8)], df5[df5['Stock'] == 'AAPL'][-1000:][int(1000*0.8):]

# %%
train_data
# Out:
#             Date     Open     High      Low    Close     Volume  OpenInt Stock
# 7364  2013-11-22   68.808   69.156   68.677   68.848   60271546        0  AAPL
# 7365  2013-11-25   69.005   69.650   69.002   69.366   61838610        0  AAPL
# 7366  2013-11-26   69.410   71.010   69.401   70.645  108093005        0  AAPL
# 7367  2013-11-27   71.032   72.316   70.645   72.311   97875204        0  AAPL
# 7368  2013-11-29   72.774   73.948   72.554   73.650   85784777        0  AAPL
# 7369  2013-12-02   73.904   74.742   72.954   73.008  127378358        0  AAPL
# 7370  2013-12-03   73.945   75.012   73.861   75.006  121442841        0  AAPL
# 7371  2013-12-04   74.899   75.386   74.278   74.832  101776136        0  AAPL
# 7372  2013-12-05   75.845   76.175   75.016   75.216  120550905        0  AAPL
# 7373  2013-12-06   74.937   75.063   74.113   74.173   92774029        0  AAPL
# 7374  2013-12-09   74.289   75.439   74.289   75.019   86349511        0  AAPL
# ...

# %%
plt.figure(figsize=(12,7))
plt.title('Apple Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.plot(df5[df5['Stock'] == 'AAPL']['High'][-1000:], 'blue', label='Training Data')
plt.plot(test_data['High'], 'green', label='Testing Data')
plt.legend()

# %%
train_data = df5[df5['Stock'] == 'FB'][-1000:][0:int(1000 * 0.8)]
test_data = df5[df5['Stock'] == 'FB'][-1000:][int(1000 * 0.8):]

# %%
train_ar = train_data['High'].values
test_ar = test_data['High'].values

# https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
history = [x for x in train_ar]
print(type(history))
predictions = list()
for t in range(len(test_ar)):
    model = ARIMA(history, order=(3,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_ar[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
# Out:
# <class 'list'>
# Testing Mean Squared Error: 3.148

# %%
plt.figure(figsize=(12,7))
plt.plot(df5[df5['Stock'] == 'AAPL']['High'][-1000:], 'green', color='blue', label='Training Data')
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['High'], color='red', label='Actual Price')
plt.title('Apple Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()

# %%
from sklearn.externals import joblib

# save the model to disk
filename = 'finalized_model.sav'
joblib.dump(model, filename)
# Out:
# ['finalized_model.sav']

# %%
train_ar = train_data['High'].values
test_ar = test_data['High'].values

loaded_model = joblib.load(filename)

# https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/
history = [x for x in train_ar]
print(type(history))
predictions = list()
for t in range(len(test_ar)):
    #model = ARIMA(history, order=(5,1,0))
    model_fit = loaded_model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_ar[t]
    history.append(obs)
    #print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
# Out:
# <class 'list'>
# Testing Mean Squared Error: 797.720

# %%
# # some time later...
 
# # load the model from disk
# loaded_model = joblib.load(filename)
# result = loaded_model.score(X_test, Y_test)
# print(result)

# %%
out = np.concatenate(predictions).ravel()
print(out)
# Out:
# [120.46967676 119.66595305 119.52339592 129.69805837 126.89354004
#  127.29785032 128.65148584 130.19506371 130.16568598 131.09008049
#  131.49702041 132.43574285 133.71294286 134.87757321 134.32879966
#  134.35836697 135.34946848 135.61854976 135.99430327 135.048562
#  136.04377262 135.86908547 138.92642224 138.63442172 138.27773888
#  138.2484199  138.4452474  138.23834411 137.15521864 137.9193007
#  137.86798414 138.14588914 139.31647206 139.45746983 139.4486159
#  140.01100415 141.34818888 139.86408871 140.09207948 140.1891081
#  139.59822833 142.80755915 142.83918512 142.94479122 142.6687465
#  142.53125438 143.39105175 143.88072723 142.82168569 142.60550411
#  142.2645778  141.71334331 140.46541314 140.87310057 140.24268985
#  140.52749217 140.42729886 141.4443951  141.0316153  142.5372896
#  143.36343756 142.96536636 142.55187155 142.7475201  145.90229532
#  146.43606322 145.8055695  145.52716134 147.56090647 152.49097761
# ...

# %%
plt.figure(figsize=(12,7))
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['Open'], color='red', label='Actual Price')
plt.title('Tesla Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.legend()
